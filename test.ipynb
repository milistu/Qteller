# %%
from qteller.GPTeller import GPTeller

# %%
teller = GPTeller(device="cpu")
# Out:
# 2024-04-15 23:00:29.439 | INFO     | qteller.GPTeller:__init__:19 - Downloading weights to cache_dir directory.
# ftfy or spacy is not installed using BERT BasicTokenizer instead of SpaCy & ftfy.
# 2024-04-15 23:00:31.215 | INFO     | qteller.GPTeller:__init__:29 - Running device: cpu.
# 2024-04-15 23:00:31.216 | INFO     | qteller.GPTeller:__init__:30 - Using openai-gpt for Query Completion with 116_534_784 parameters.

# %%
teller.complete(query="Silver ", context="jewelry store", max_length=5)
# Out:
# ['silver and silver. "',
#  'silver. " i\'m',
#  'silver, and a pair of',
#  'silver and gold. "',
#  'silver - plated, and a']
